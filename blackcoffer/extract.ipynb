# %%
import os
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
df = pd.read_excel('input.xlsx')

output_directory = 'extracted_articles'
os.makedirs(output_directory, exist_ok=True)

# %%
for index, row in df.iterrows():
    url = row['URL']
    url_id = row['URL_ID']

   
    response = requests.get(url)

    if response.status_code == 200:
       
        soup = BeautifulSoup(response.content, 'html.parser')

       
        title = soup.find('title').get_text()

       
        article_text = ''
        for paragraph in soup.find_all('p'):
            article_text += paragraph.get_text() + '\n'

        
        output_file_path = os.path.join(output_directory, f'{url_id}.txt')
        with open(output_file_path, 'w', encoding='utf-8') as file:
            file.write(f'Title: {title}\n\n')
            file.write(article_text)

        print(f'Saved article from {url_id} to {output_file_path}')
    else:
        print(f'Failed to fetch data from {url_id}')

print('Data extraction completed.')
# Out:
# Saved article from 123.0 to extracted_articles\123.0.txt
# Saved article from 321.0 to extracted_articles\321.0.txt
# Saved article from 2345.0 to extracted_articles\2345.0.txt
# Saved article from 4321.0 to extracted_articles\4321.0.txt
# Saved article from 432.0 to extracted_articles\432.0.txt
# Saved article from 2893.8 to extracted_articles\2893.8.txt
# Saved article from 3355.6 to extracted_articles\3355.6.txt
# Saved article from 3817.4 to extracted_articles\3817.4.txt
# Saved article from 4279.2 to extracted_articles\4279.2.txt
# Saved article from 4741.0 to extracted_articles\4741.0.txt
# Saved article from 5202.8 to extracted_articles\5202.8.txt
# Saved article from 5664.6 to extracted_articles\5664.6.txt
# Saved article from 6126.4 to extracted_articles\6126.4.txt
# Saved article from 6588.2 to extracted_articles\6588.2.txt
# Saved article from 7050.0 to extracted_articles\7050.0.txt
# Saved article from 7511.8 to extracted_articles\7511.8.txt
# Saved article from 7973.6 to extracted_articles\7973.6.txt
# Saved article from 8435.4 to extracted_articles\8435.4.txt
# Saved article from 8897.2 to extracted_articles\8897.2.txt
# Saved article from 9359.0 to extracted_articles\9359.0.txt
# Saved article from 9820.8 to extracted_articles\9820.8.txt
# Saved article from 10282.6 to extracted_articles\10282.6.txt
# Saved article from 10744.4 to extracted_articles\10744.4.txt
# Saved article from 11206.2 to extracted_articles\11206.2.txt
# Failed to fetch data from 11668.0
# Saved article from 12129.8 to extracted_articles\12129.8.txt
# Saved article from 12591.6 to extracted_articles\12591.6.txt
# Saved article from 13053.4 to extracted_articles\13053.4.txt
# Saved article from 13515.2 to extracted_articles\13515.2.txt
# Saved article from 13977.0 to extracted_articles\13977.0.txt
# Saved article from 14438.8 to extracted_articles\14438.8.txt
# Saved article from 14900.6 to extracted_articles\14900.6.txt
# Saved article from 15362.4 to extracted_articles\15362.4.txt
# Saved article from 15824.2 to extracted_articles\15824.2.txt
# Saved article from 16286.0 to extracted_articles\16286.0.txt
# Saved article from 16747.8 to extracted_articles\16747.8.txt
# Saved article from 17209.6 to extracted_articles\17209.6.txt
# Failed to fetch data from 17671.4
# Saved article from 18133.2 to extracted_articles\18133.2.txt
# Saved article from 18595.0 to extracted_articles\18595.0.txt
# Saved article from 19056.8 to extracted_articles\19056.8.txt
# Saved article from 19518.6 to extracted_articles\19518.6.txt
# Saved article from 19980.4 to extracted_articles\19980.4.txt
# Saved article from 20442.2 to extracted_articles\20442.2.txt
# Saved article from 20904.0 to extracted_articles\20904.0.txt
# Saved article from 21365.8 to extracted_articles\21365.8.txt
# Saved article from 21827.6 to extracted_articles\21827.6.txt
# Saved article from 22289.4 to extracted_articles\22289.4.txt
# Saved article from 22751.2 to extracted_articles\22751.2.txt
# Saved article from 23213.0 to extracted_articles\23213.0.txt
# Saved article from 23674.8 to extracted_articles\23674.8.txt
# Saved article from 24136.6 to extracted_articles\24136.6.txt
# Saved article from 24598.4 to extracted_articles\24598.4.txt
# Saved article from 25060.2 to extracted_articles\25060.2.txt
# Saved article from 25522.0 to extracted_articles\25522.0.txt
# Saved article from 25983.8 to extracted_articles\25983.8.txt
# Saved article from 26445.6 to extracted_articles\26445.6.txt
# Saved article from 26907.4 to extracted_articles\26907.4.txt
# Saved article from 27369.2 to extracted_articles\27369.2.txt
# Saved article from 27831.0 to extracted_articles\27831.0.txt
# Saved article from 28292.8 to extracted_articles\28292.8.txt
# Saved article from 28754.6 to extracted_articles\28754.6.txt
# Saved article from 29216.4 to extracted_articles\29216.4.txt
# Saved article from 29678.2 to extracted_articles\29678.2.txt
# Saved article from 30140.0 to extracted_articles\30140.0.txt
# Saved article from 30601.8 to extracted_articles\30601.8.txt
# Saved article from 31063.6 to extracted_articles\31063.6.txt
# Saved article from 31525.4 to extracted_articles\31525.4.txt
# Saved article from 31987.2 to extracted_articles\31987.2.txt
# Saved article from 32449.0 to extracted_articles\32449.0.txt
# Saved article from 32910.8 to extracted_articles\32910.8.txt
# Saved article from 33372.6 to extracted_articles\33372.6.txt
# Saved article from 33834.4 to extracted_articles\33834.4.txt
# Saved article from 34296.2 to extracted_articles\34296.2.txt
# Saved article from 34758.0 to extracted_articles\34758.0.txt
# Saved article from 35219.8 to extracted_articles\35219.8.txt
# Saved article from 35681.6 to extracted_articles\35681.6.txt
# Saved article from 36143.4 to extracted_articles\36143.4.txt
# Saved article from 36605.2 to extracted_articles\36605.2.txt
# Saved article from 37067.0 to extracted_articles\37067.0.txt
# Saved article from 37528.8 to extracted_articles\37528.8.txt
# Saved article from 37990.6 to extracted_articles\37990.6.txt
# Saved article from 38452.4 to extracted_articles\38452.4.txt
# Saved article from 38914.2 to extracted_articles\38914.2.txt
# Saved article from 39376.0 to extracted_articles\39376.0.txt
# Saved article from 39837.8 to extracted_articles\39837.8.txt
# Saved article from 40299.6 to extracted_articles\40299.6.txt
# Saved article from 40761.4 to extracted_articles\40761.4.txt
# Saved article from 41223.2 to extracted_articles\41223.2.txt
# Saved article from 41685.0 to extracted_articles\41685.0.txt
# Saved article from 42146.8 to extracted_articles\42146.8.txt
# Saved article from 42608.6 to extracted_articles\42608.6.txt
# Saved article from 43070.4 to extracted_articles\43070.4.txt
# Saved article from 43532.2 to extracted_articles\43532.2.txt
# Saved article from 43994.0 to extracted_articles\43994.0.txt
# Saved article from 44455.8 to extracted_articles\44455.8.txt
# Saved article from 44917.6 to extracted_articles\44917.6.txt
# Saved article from 45379.4 to extracted_articles\45379.4.txt
# Saved article from 45841.2 to extracted_articles\45841.2.txt
# Saved article from 46303.0 to extracted_articles\46303.0.txt
# Saved article from 46764.8 to extracted_articles\46764.8.txt
# Saved article from 47226.6 to extracted_articles\47226.6.txt
# Saved article from 47688.4 to extracted_articles\47688.4.txt
# Saved article from 48150.2 to extracted_articles\48150.2.txt
# Saved article from 48612.0 to extracted_articles\48612.0.txt
# Saved article from 49073.8 to extracted_articles\49073.8.txt
# Saved article from 49535.6 to extracted_articles\49535.6.txt
# Saved article from 49997.4 to extracted_articles\49997.4.txt
# Saved article from 50459.2 to extracted_articles\50459.2.txt
# Saved article from 50921.0 to extracted_articles\50921.0.txt
# Saved article from 51382.8 to extracted_articles\51382.8.txt
# Saved article from 51844.6 to extracted_articles\51844.6.txt
# Saved article from 52306.4 to extracted_articles\52306.4.txt
# Saved article from 52768.2 to extracted_articles\52768.2.txt
# Data extraction completed.
